# %% [markdown]
# 1. Instalación

# %%
pip install scikit-image

# %% [markdown]
# 2. Importación

# %%
import skimage
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import resize

# %% [markdown]
# 3. Ejemplo con la carga de imágenes
#   * Cámara

# %%
# Cargar imagen de skimage.data
camera = skimage.data.camera()
# Explorar la imagen
print(type(camera))
print(camera.shape)
# Mostrar la imagen
skimage.io.imshow(camera)
skimage.io.show()
# Out:
# <class 'numpy.ndarray'>
# (512, 512)

# %% [markdown]
#   * Astronauta

# %%
# Cargar imagen de skimage.data
astronaut = skimage.data.astronaut()
# Explorar la imagen
print(type(astronaut))
print(astronaut.shape)
# Mostrar la imagen
skimage.io.imshow(astronaut)
skimage.io.show()
# Out:
# <class 'numpy.ndarray'>
# (512, 512, 3)

# %% [markdown]
# 4. Carga de una imagen y transformaciones

# %%
import matplotlib.pyplot as plt
from skimage.transform import resize

# Ruta de la imagen
imagen_path = '/content/images.jpg'

# Cargar la imagen
image = skimage.io.imread(imagen_path)

# Rotar la imagen 90 grados en sentido antihorario
rotated_image = skimage.transform.rotate(image, angle=90)

# Aplicar un filtro Gaussiano para suavizar la imagen
smoothed_image = skimage.filters.gaussian(image, sigma = 2)

image = resize(image, (300, 300))
rotated_image = resize(rotated_image, (300, 300))
smoothed_image = resize(smoothed_image, (300, 300))

import numpy as np
matriz_imagenes = np.array([image, rotated_image, smoothed_image])

#Mostrando la matriz de imágenes (si deseas visualizarlas)

fig, axs = plt.subplots(nrows=1, ncols=3, figsize = (20,20))
for i in range(3):
    axs[i].imshow(matriz_imagenes[i])
    axs[i].axis('off')  # Desactiva los ejes
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:348: RuntimeWarning: Images with dimensions (M, N, 3) are interpreted as 2D+RGB by default. Use `multichannel=False` to interpret as 3D image with last dimension of length 3.
#   return func(*args, **kwargs)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
